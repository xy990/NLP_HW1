# %% [markdown]
# ## Learning Rate: SGD with momentum =0.9, learning rate = [0.01, 0.1 ,1]

# %%
import pandas as pd
import matplotlib.pyplot as plt
#train_result=pd.read_csv("training_set.csv")
#train_result.plot()
x= list(range(10))
y1 = [0.676,0.643,0.623,0.609,0.604,0.592,0.584,0.574,0.572,0.564]
y2=[0.578,0.516,0.487,0.451,0.425,0.418,0.408,0.383,0.374,0.371]
y3=[0.496,0.424,0.38,0.361,0.353,0.335,0.306,0.306,0.298,0.278]

plt.plot(x, y1,linestyle='dashed',marker='o',color='b')
plt.plot(x, y2,linestyle='dashed',marker='o',color='r')
plt.plot(x, y3,linestyle='dashed',marker='o',color='g')

plt.legend(['learning_rate=0.01', 'learning_rate=0.1','learning_rate=1'],loc='upper left', bbox_to_anchor=(1, 1.05))
plt.xlabel('number of epochs')
plt.ylabel("training loss")
plt.title(' Training Loss of Learning Rate')
plt.savefig("train_loss_lr.jpeg")
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
#train_result=pd.read_csv("training_set.csv")
#train_result.plot()
x= list(range(10))
y1 = [63.9,65.42,66.06,66.86,67.44,67.96,67.92,69.26,69.46,70.46]
y2=[70.7,73.06,76.2,77.7,77.32,79.26,79.68,79.82,80.32,81.28]
y3=[78,80.62,80.8,76.82,77.86,83.52,80.96,82.98,81.42,80.22]

plt.plot(x, y1,linestyle='dashed',marker='v',color='b')
plt.plot(x, y2,linestyle='dashed',marker='v',color='r')
plt.plot(x, y3,linestyle='dashed',marker='v',color='g')

plt.legend(['learning_rate=0.01', 'learning_rate=0.1','learning_rate=1'],loc='upper left', bbox_to_anchor=(1, 1.05))
plt.xlabel('number of epochs')
plt.ylabel("Validation Accuracy")
plt.title('Validation Accuracy of Learning Rate')
plt.savefig("val_acc_lr.png")
plt.show()

# %% [markdown]
# # N-gram = [1,2,3,4]

# %%
import pandas as pd
import matplotlib.pyplot as plt
#train_result=pd.read_csv("training_set.csv")
#train_result.plot()
x= list(range(10))
y1 = [0.652,0.468,0.356,0.301,0.269,0.235,0.215,0.205,0.188,0.167]
y2=[0.674,0.543,0.421,0.355,0.319,0.297,0.264,0.243,0.231,0.214]
y3=[0.691,0.659,0.596,0.527,0.467,0.429,0.396,0.373,0.344,0.329]
y4=[0.697,0.689,0.675,0.649,0.649,0.581,0.549,0.521,0.498,0.47]

plt.plot(x, y1,linestyle='dashed',marker='o',color='b')
plt.plot(x, y2,linestyle='dashed',marker='o',color='r')
plt.plot(x, y3,linestyle='dashed',marker='o',color='g')
plt.plot(x, y4,linestyle='dashed',marker='o',color='y')

plt.legend(['ngram = 1', 'ngram = 2','ngram = 3','ngram = 4'],loc='best', bbox_to_anchor=(1, 1.05))
plt.xlabel('number of epochs')
plt.ylabel("training loss")
plt.title(' Training Loss of N-gram')
plt.savefig("train_loss_ngram.jpeg")
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
#train_result=pd.read_csv("training_set.csv")
#train_result.plot()
x= list(range(10))

y1 = [71.56,81.76,82.86,84.42,84.94, 84.74, 84.92, 85.06, 84.96, 84.62]
y2 = [67.92, 78.8, 81.14, 81.76, 82.62, 82.88, 83.26, 82.88, 83.1, 82.98]
y3 = [65.56, 66.94, 70.04, 75.14, 76.06, 75.58, 77.78, 77.36,77.98, 78.4]
y4 = [50.6, 51, 54.68, 56.48, 69.2, 69.58, 70.2, 68.2, 68.56, 71.52]


plt.plot(x, y1,linestyle='dashed',marker='v',color='b')
plt.plot(x, y2,linestyle='dashed',marker='v',color='r')
plt.plot(x, y3,linestyle='dashed',marker='v',color='g')
plt.plot(x, y4,linestyle='dashed',marker='v',color='y')

plt.legend(['ngram = 1', 'ngram = 2','ngram = 3','ngram = 4'],loc='upper left', bbox_to_anchor=(1, 1.05))
plt.xlabel('number of epochs')
plt.ylabel("Validation Accuracy")
plt.title('Validation Accuracy of N-grams')
plt.savefig("val_acc_ngram.jpeg")
plt.show()

# %% [markdown]
# # Embedding Size

# %%
import pandas as pd
import matplotlib.pyplot as plt
#train_result=pd.read_csv("training_set.csv")
#train_result.plot()
x= list(range(10))
y1 = [0.691,0.562,0.425,0.35,0.307,0.281,0.259,0.24,0.223,0.201]
y2 = [0.652, 0.468, 0.356, 0.301, 0.269, 0.235, 0.215, 0.205,0.188,0.167]
y3=[0.581,0.385,0.31,0.259,0.23,0.2,0.183,0.161,0.15,0.135]


plt.plot(x, y1,linestyle='dashed',marker='o',color='b')
plt.plot(x, y2,linestyle='dashed',marker='o',color='r')
plt.plot(x, y3,linestyle='dashed',marker='o',color='g')


plt.legend(['Embed size = 50', 'Embed size = 100','Embed size = 200'],loc='upper left', bbox_to_anchor=(1, 1.05))
plt.xlabel('number of epochs')
plt.ylabel("training loss")
plt.title(' Training Loss of Embed Size')
plt.savefig("train_loss_EmbedSize.jpeg")
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
#train_result=pd.read_csv("training_set.csv")
#train_result.plot()
x= list(range(10))
y1 = [65.52,77.9,81.96,83.2,83.76,84.02,84.16,84.12,84.08,83.9]
y2 = [71.56,81.76,82.86,84.42,84.94,84.74, 84.92, 85.06, 84.96,84.62]
y3=[77.16,83.16,84.36,84.6,84.62,84.4,83.6,84,83.74,83.3]


plt.plot(x, y1,linestyle='dashed',marker='v',color='b')
plt.plot(x, y2,linestyle='dashed',marker='v',color='r')
plt.plot(x, y3,linestyle='dashed',marker='v',color='g')


plt.legend(['Embed size = 50', 'Embed size = 100','Embed size = 200'],loc='upper left', bbox_to_anchor=(1, 1.05))
plt.xlabel('number of epochs')
plt.ylabel("Validation Accuracy")
plt.title('Validation Accuracy of Embed Size')
plt.savefig("val_acc_EmbedSize.jpeg")
plt.show()

# %% [markdown]
# # SGD VS Adam

# %% [markdown]
# # change the learning rate to adjust the performance of SGD and Adam, compare two models with best performance using SGD and Adam

# %%
import pandas as pd
import matplotlib.pyplot as plt
#train_result=pd.read_csv("training_set.csv")
#train_result.plot()
x= list(range(10))
y1 = [0.676,0.643,0.623,0.609,0.604,0.592,0.584,0.574,0.572,0.564]
y2=[0.578,0.516,0.487,0.451,0.425,0.418,0.408,0.383,0.374,0.371]
y3=[0.496,0.424,0.38,0.361,0.353,0.335,0.306,0.306,0.298,0.278]

y5 = [0.363, 0.405, 0.313, 0.31, 0.274, 0.304, 0.259, 0.304, 0.276, 0.283]
y6 = [0.652, 0.468, 0.356, 0.301, 0.269, 0.235, 0.215, 0.205, 0.188, 0.167]

plt.plot(x, y1,linestyle='dashed',marker='o',color='b')
plt.plot(x, y2,linestyle='dashed',marker='o',color='r')
plt.plot(x, y3,linestyle='dashed',marker='o',color='g')


plt.plot(x, y5,linestyle='dashed',marker='v',color='r')
plt.plot(x, y6,linestyle='dashed',marker='v',color='g')

plt.legend(['SGD_learning_rate=0.01', 'SGD_learning_rate=0.1','SGD_learning_rate=1',  'Adam_learning_rate=0.1',  'Adam_learning_rate=0.001'],loc='upper left', bbox_to_anchor=(1, 1.05))
plt.xlabel('number of epochs')
plt.ylabel("training loss")
plt.title(' Training Loss of SGD vs Adam')
plt.savefig("train_loss_lr.jpeg")
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
#train_result=pd.read_csv("training_set.csv")
#train_result.plot()
x= list(range(10))
y1 = [63.9,65.42,66.06,66.86,67.44,67.96,67.92,69.26,69.46,70.46]
y2=[70.7,73.06,76.2,77.7,77.32,79.26,79.68,79.82,80.32,81.28]
y3=[78,80.62,80.8,76.82,77.86,83.52,80.96,82.98,81.42,80.22]
y5 = [80.14,79.94,80.72,78.22,78.18,78.44,74.02,77.38,77.54, 76.6]
y6 =[71.56,81.76,82.86,84.42,84.94,84.74,84.92,85.06,84.96,84.62]



plt.plot(x, y1,linestyle='dashed',marker='v',color='b')
plt.plot(x, y2,linestyle='dashed',marker='v',color='r')
plt.plot(x, y3,linestyle='dashed',marker='v',color='g')

plt.plot(x, y5,linestyle='dashed',marker='o',color='r')
plt.plot(x, y6,linestyle='dashed',marker='o',color='g')

plt.legend(['SGD_learning_rate=0.01', 'SGD_learning_rate=0.1','SGD_learning_rate=1',  'Adam_learning_rate=0.1',  'Adam_learning_rate=0.001'],loc='upper left', bbox_to_anchor=(1, 1.05))
plt.xlabel('number of epochs')
plt.ylabel("Validation Accuracy")
plt.title('Validation Accuracy of SGD vs Adam')
plt.savefig("val_acc_lr.jpeg")
plt.show()

# %% [markdown]
# # Tokenize
# # remove Punc, stop words + stem
# # remove punctuation
# # remove stop words
# # Stemming

# %%
import pandas as pd
import matplotlib.pyplot as plt
#train_result=pd.read_csv("training_set.csv")
#train_result.plot()
x= list(range(6))
y1 = [0.644,0.454,0.346,0.301,0.265,0.244]
y2 = [0.65,0.469,0.36,0.295,0.26,0.24]
y3= [0.636,0.411,0.304,0.259,0.22,0.198]
y4= [0.656,0.475,0.358,0.312,0.274,0.249]


plt.plot(x, y1,linestyle='dashed',marker='o',color='b')
plt.plot(x, y2,linestyle='dashed',marker='o',color='r')
plt.plot(x, y3,linestyle='dashed',marker='o',color='g')
plt.plot(x, y4,linestyle='dashed',marker='o',color='y')

plt.legend(['remove Punctuation+ stop words + stemming', 'remove punctuation','remove stop words', 'stemming'],loc='upper left', bbox_to_anchor=(1, 1.05))
plt.xlabel('number of epochs')
plt.ylabel("training loss")
plt.title(' Training Loss of Tokenize')
plt.savefig("train_loss_tokenize.jpeg")
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
#train_result=pd.read_csv("training_set.csv")
#train_result.plot()
x= list(range(6))
y1 = [73.28, 81.06, 83.2, 84.2, 84.52, 84.6]
y2 = [71.3, 80.66, 83.34, 84.02, 84.58, 84.98]
y3= [76.3, 83.32, 84.66, 85.3, 85.64, 86.02]
y4= [72.74, 80.5, 82.5, 83.64, 83.96, 83.86]


plt.plot(x, y1,linestyle='dashed',marker='v',color='b')
plt.plot(x, y2,linestyle='dashed',marker='v',color='r')
plt.plot(x, y3,linestyle='dashed',marker='v',color='g')
plt.plot(x, y4,linestyle='dashed',marker='v',color='y')

plt.legend(['remove Punctuation+ stop words + stemming', 'remove punctuation','remove stop words', 'stemming'],loc='upper left', bbox_to_anchor=(1, 1.05))
plt.xlabel('number of epochs')
plt.ylabel("Validation Accuracy")
plt.title('Validation Accuracy of Tokenize')
plt.savefig("val_acc_tokenize.jpeg")
plt.show()

# %% [markdown]
# # Vocabulary Size [5000, 10000, 20000]

# %%
import pandas as pd
import matplotlib.pyplot as plt

x= list(range(10))
y1 = [0.644, 0.466, 0.365, 0.324, 0.293, 0.276, 0.254, 0.247, 0.228, 0.222]
y2 = [0.652, 0.468, 0.356, 0.301, 0.269, 0.235, 0.215, 0.205, 0.188, 0.167]
y3= [0.644, 0.443, 0.333, 0.274, 0.236, 0.203, 0.18, 0.16, 0.136, 0.116]



plt.plot(x, y1,linestyle='dashed',marker='o',color='b')
plt.plot(x, y2,linestyle='dashed',marker='o',color='r')
plt.plot(x, y3,linestyle='dashed',marker='o',color='g')


plt.legend(['voc_size = 5000', 'voc_size = 10000','voc_size = 20000'],loc='best', bbox_to_anchor=(1, 1.05))
plt.xlabel('number of epochs')
plt.ylabel("training loss")
plt.title(' Training Loss of Vocabulary Size')
plt.savefig("train_loss_vocsize.jpeg")
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

x= list(range(10))
y1 = [72.3,81.42, 83.46, 84.4, 84.76, 84.96, 85.04, 84.74, 84.58, 84.36]
y2 = [71.56, 81.76, 82.86, 84.42, 84.94, 84.74, 84.92, 85.06, 84.96, 84.62]
y3= [74.04, 81.22, 82.6, 84.3, 84.78, 84.74, 84.3, 84.56, 83.82, 84.12]



plt.plot(x, y1,linestyle='dashed',marker='o',color='b')
plt.plot(x, y2,linestyle='dashed',marker='o',color='r')
plt.plot(x, y3,linestyle='dashed',marker='o',color='g')


plt.legend(['voc_size = 5000', 'voc_size = 10000','voc_size = 20000'],loc='upper left', bbox_to_anchor=(1, 1.05))
plt.xlabel('number of epochs')
plt.ylabel("Validation Accuracy")
plt.title('Validation Accuracy of Vocabulary Size')
plt.savefig("val_acc_vocsize.jpeg")
plt.show()
